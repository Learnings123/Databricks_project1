# %%
notebooks = ['/Workspace/Users/monikalearnings@gmail.com/databricks_project1/gold_dim_customers',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/gold_dim_product',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/gold_fact_sales'

]

for nb in notebooks:
  dbutils.notebook.run(nb,timeout_seconds=0)
