# %%
notebooks = ['/Workspace/Users/monikalearnings@gmail.com/databricks_project1/(Clone) Silver_crm_cust',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/Silver_crm_products',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/Silver_crm_sales',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/Silver_erp_cust',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/Silver_erp_location',
             '/Workspace/Users/monikalearnings@gmail.com/databricks_project1/Silver_erp_prodcat']

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
